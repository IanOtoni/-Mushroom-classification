# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('mushrooms.csv') #Le o dataset
display(df.head()) #mostra as 5 primeiras amostras
colum_names = df.columns
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
for name in colum_names: #verifica o balanceamento do dataset
    print('============================================')
    print(df[name].value_counts())
# Out:
# ...
# class
# e    4208
# p    3916
# Name: count, dtype: int64
# ...
# cap-shape
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: count, dtype: int64
# ...
# cap-surface
# y    3244
# s    2556
# f    2320
# g       4
# Name: count, dtype: int64
# ...
# cap-color
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# u      16
# r      16
# Name: count, dtype: int64
# ...
# bruises
# f    4748
# t    3376
# Name: count, dtype: int64
# ...
# odor
# n    3528
# f    2160
# s     576
# y     576
# a     400
# l     400
# p     256
# c     192
# m      36
# Name: count, dtype: int64
# ...
# gill-attachment
# f    7914
# a     210
# Name: count, dtype: int64
# ...
# gill-spacing
# c    6812
# w    1312
# Name: count, dtype: int64
# ...
# gill-size
# b    5612
# n    2512
# Name: count, dtype: int64
# ...
# gill-color
# b    1728
# p    1492
# w    1202
# n    1048
# g     752
# h     732
# u     492
# k     408
# e      96
# y      86
# o      64
# r      24
# ...

# %%
print("Dados faltantes em cada feature:")
print(df.isnull().sum())
# Out:
# Dados faltantes em cada feature:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df = df.drop('veil-type', axis=1)   
print("\nDimensões do dataset após a remoção:", df.shape)

# A coluna 'class' é o nosso alvo (label)
# p = poisonous (venenoso), e = edible (comestível)
y = df['class']

# X são todas as outras colunas (features)
X = df.drop('class', axis=1)

print("Label 'y' separado:")
print(y.head())
print("\nFeatures 'X' separadas:")
display(X.head())
# Out:
# Dimensões do dataset após a remoção: (8124, 22)
# Label 'y' separado:
# 0    p
# 1    e
# 2    e
# 3    p
# 4    e
# Name: class, dtype: object
#
# Features 'X' separadas:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-surface-above-ring  \
# 0         n          k           e  ...                        s
# 1         b          k           e  ...                        s
# 2         b          n           e  ...                        s
# 3         n          n           e  ...                        s
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Instanciar o codificador
le = LabelEncoder()

# Aplicar a codificação em y
y_encoded = le.fit_transform(y)

# Mostrar a correspondência da codificação
# (ex: 'e' -> 0, 'p' -> 1)
print(f"Labels originais: {le.classes_}")
print(f"Labels codificados: {np.unique(y_encoded)}")
print("\nExemplo dos 5 primeiros labels codificados:", y_encoded[:5])
# Out:
# Labels originais: ['e' 'p']
# Labels codificados: [0 1]
#
# Exemplo dos 5 primeiros labels codificados: [1 0 0 1 0]

# %% [markdown]
# # Aplicar One-Hot Encoding em todo o dataframe X
# X_encoded = pd.get_dummies(X)
#
# print("Dimensões de X após o One-Hot Encoding:", X_encoded.shape)
# print("\nAmostra das features codificadas:")
# display(X_encoded.head())

# %%
from sklearn.model_selection import train_test_split

# Dividir os dados
# test_size=0.2 significa 20% para teste e 80% para treino
# random_state=42 garante que a divisão seja a mesma toda vez que rodarmos o código
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y_encoded, test_size=0.2, random_state=42
)

print("Dimensões dos dados de treino:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

print("\nDimensões dos dados de teste:")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       1 from sklearn.model_selection import train_test_split
#       3 # Dividir os dados
#       4 # test_size=0.2 significa 20% para teste e 80% para treino
#       5 # random_state=42 garante que a divisão seja a mesma toda vez que rodarmos o código
#       6 X_train, X_test, y_train, y_test = train_test_split(
# ----> 7     X_encoded, y_encoded, test_size=0.2, random_state=42
#       8 )
#      10 print("Dimensões dos dados de treino:")
#      11 print(f"X_train: {X_train.shape}")
#
# NameError: name 'X_encoded' is not defined
