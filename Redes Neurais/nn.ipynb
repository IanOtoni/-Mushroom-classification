# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow import keras
import seaborn as sns

# %%
df = pd.read_csv("mushrooms.csv")
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
#  13  stalk-surface-below-ring  8124 non-null   object
#  14  stalk-color-above-ring    8124 non-null   object
#  15  stalk-color-below-ring    8124 non-null   object
#  16  veil-type                 8124 non-null   object
#  17  veil-color                8124 non-null   object
#  18  ring-number               8124 non-null   object
#  19  ring-type                 8124 non-null   object
#  20  spore-print-color         8124 non-null   object
#  21  population                8124 non-null   object
#  22  habitat                   8124 non-null   object
# dtypes: object(23)
# memory usage: 1.4+ MB

# %%
le = LabelEncoder()

# %%
for col in df.columns:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
x = df.drop(columns='class')
y = df['class']

# %%
x.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# 2             0          0           5            0  ...
# 3             0          1           5            0  ...
# 4             1          0           4            1  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# 1                         2                       7                       7
# 2                         2                       7                       7
# 3                         2                       7                       7
# 4                         2                       7                       7
#
#    veil-type  veil-color  ring-number  ring-type  spore-print-color  \
# 0          0           2            1          4                  2
# 1          0           2            1          4                  3
# 2          0           2            1          4                  3
# 3          0           2            1          4                  2
# 4          0           2            1          0                  3
#
#    population  habitat
# 0           3        5
# 1           2        1
# 2           2        3
# 3           3        5
# 4           0        1
#
# [5 rows x 22 columns]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, shuffle=True, random_state=69)

# %%
print(f'x_train.shape: {x_train.shape} \ny_train.shape: {y_train.shape} \nx_test.shape: {x_test.shape} \ny_test.shape: {y_test.shape}\n ')
# Out:
# x_train.shape: (6093, 22)
# y_train.shape: (6093,)
# x_test.shape: (2031, 22)
# y_test.shape: (2031,)

# %%
y_train = keras.utils.to_categorical(y_train, num_classes=2)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(units=32, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=2, activation='softmax'))
# Out:
# C:\Users\Ian\OneDrive\Área de Trabalho\CCP\7 Semestre\INF 420\Trabalho Final\venv\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,914 (11.38 KB)
#  Trainable params: 2,914 (11.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train, y_train, batch_size=500, epochs=100, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/100
# 10/10 - 1s - 94ms/step - accuracy: 0.5246 - loss: 1.1679 - val_accuracy: 0.5455 - val_loss: 0.6715
# Epoch 2/100
# 10/10 - 0s - 7ms/step - accuracy: 0.5691 - loss: 0.8154 - val_accuracy: 0.6801 - val_loss: 0.5612
# Epoch 3/100
# 10/10 - 0s - 7ms/step - accuracy: 0.6381 - loss: 0.6651 - val_accuracy: 0.7186 - val_loss: 0.5221
# Epoch 4/100
# 10/10 - 0s - 7ms/step - accuracy: 0.6485 - loss: 0.6216 - val_accuracy: 0.7613 - val_loss: 0.5006
# Epoch 5/100
# 10/10 - 0s - 7ms/step - accuracy: 0.6801 - loss: 0.5834 - val_accuracy: 0.8031 - val_loss: 0.4697
# Epoch 6/100
# 10/10 - 0s - 8ms/step - accuracy: 0.7039 - loss: 0.5567 - val_accuracy: 0.8326 - val_loss: 0.4383
# Epoch 7/100
# 10/10 - 0s - 8ms/step - accuracy: 0.7269 - loss: 0.5208 - val_accuracy: 0.8663 - val_loss: 0.4054
# Epoch 8/100
# 10/10 - 0s - 7ms/step - accuracy: 0.7366 - loss: 0.5010 - val_accuracy: 0.8745 - val_loss: 0.3735
# Epoch 9/100
# 10/10 - 0s - 7ms/step - accuracy: 0.7737 - loss: 0.4594 - val_accuracy: 0.8761 - val_loss: 0.3502
# Epoch 10/100
# 10/10 - 0s - 7ms/step - accuracy: 0.7915 - loss: 0.4392 - val_accuracy: 0.8884 - val_loss: 0.3138
# Epoch 11/100
# 10/10 - 0s - 7ms/step - accuracy: 0.8139 - loss: 0.4023 - val_accuracy: 0.8901 - val_loss: 0.2834
# Epoch 12/100
# 10/10 - 0s - 7ms/step - accuracy: 0.8336 - loss: 0.3743 - val_accuracy: 0.9024 - val_loss: 0.2558
# Epoch 13/100
# 10/10 - 0s - 7ms/step - accuracy: 0.8430 - loss: 0.3480 - val_accuracy: 0.9057 - val_loss: 0.2334
# Epoch 14/100
# 10/10 - 0s - 7ms/step - accuracy: 0.8543 - loss: 0.3259 - val_accuracy: 0.9106 - val_loss: 0.2093
# Epoch 15/100
# 10/10 - 0s - 7ms/step - accuracy: 0.8673 - loss: 0.3016 - val_accuracy: 0.9253 - val_loss: 0.1954
# Epoch 16/100
# 10/10 - 0s - 8ms/step - accuracy: 0.8769 - loss: 0.2804 - val_accuracy: 0.9344 - val_loss: 0.1736
# Epoch 17/100
# 10/10 - 0s - 8ms/step - accuracy: 0.8851 - loss: 0.2654 - val_accuracy: 0.9434 - val_loss: 0.1663
# Epoch 18/100
# 10/10 - 0s - 7ms/step - accuracy: 0.8929 - loss: 0.2518 - val_accuracy: 0.9450 - val_loss: 0.1517
# Epoch 19/100
# 10/10 - 0s - 7ms/step - accuracy: 0.8993 - loss: 0.2385 - val_accuracy: 0.9524 - val_loss: 0.1447
# Epoch 20/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9056 - loss: 0.2252 - val_accuracy: 0.9500 - val_loss: 0.1331
# Epoch 21/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9136 - loss: 0.2151 - val_accuracy: 0.9557 - val_loss: 0.1285
# Epoch 22/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9089 - loss: 0.2065 - val_accuracy: 0.9623 - val_loss: 0.1255
# Epoch 23/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9146 - loss: 0.1994 - val_accuracy: 0.9532 - val_loss: 0.1115
# Epoch 24/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9220 - loss: 0.1834 - val_accuracy: 0.9631 - val_loss: 0.1095
# Epoch 25/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9276 - loss: 0.1747 - val_accuracy: 0.9672 - val_loss: 0.1029
# Epoch 26/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9321 - loss: 0.1658 - val_accuracy: 0.9606 - val_loss: 0.0983
# Epoch 27/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9346 - loss: 0.1610 - val_accuracy: 0.9721 - val_loss: 0.0962
# Epoch 28/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9374 - loss: 0.1540 - val_accuracy: 0.9696 - val_loss: 0.0865
# Epoch 29/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9387 - loss: 0.1530 - val_accuracy: 0.9737 - val_loss: 0.0819
# Epoch 30/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9444 - loss: 0.1371 - val_accuracy: 0.9754 - val_loss: 0.0786
# Epoch 31/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9413 - loss: 0.1407 - val_accuracy: 0.9787 - val_loss: 0.0741
# Epoch 32/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9485 - loss: 0.1277 - val_accuracy: 0.9787 - val_loss: 0.0721
# Epoch 33/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9485 - loss: 0.1288 - val_accuracy: 0.9828 - val_loss: 0.0658
# Epoch 34/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9491 - loss: 0.1215 - val_accuracy: 0.9828 - val_loss: 0.0632
# Epoch 35/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9510 - loss: 0.1214 - val_accuracy: 0.9861 - val_loss: 0.0573
# Epoch 36/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9510 - loss: 0.1140 - val_accuracy: 0.9836 - val_loss: 0.0558
# Epoch 37/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9586 - loss: 0.1069 - val_accuracy: 0.9885 - val_loss: 0.0524
# Epoch 38/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9559 - loss: 0.1057 - val_accuracy: 0.9869 - val_loss: 0.0500
# Epoch 39/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9588 - loss: 0.1012 - val_accuracy: 0.9877 - val_loss: 0.0461
# Epoch 40/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9567 - loss: 0.0992 - val_accuracy: 0.9902 - val_loss: 0.0426
# Epoch 41/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9631 - loss: 0.0921 - val_accuracy: 0.9877 - val_loss: 0.0423
# Epoch 42/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9588 - loss: 0.0952 - val_accuracy: 0.9918 - val_loss: 0.0391
# Epoch 43/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9620 - loss: 0.0900 - val_accuracy: 0.9893 - val_loss: 0.0402
# Epoch 44/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9586 - loss: 0.0960 - val_accuracy: 0.9902 - val_loss: 0.0356
# Epoch 45/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9688 - loss: 0.0786 - val_accuracy: 0.9926 - val_loss: 0.0331
# Epoch 46/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9631 - loss: 0.0825 - val_accuracy: 0.9934 - val_loss: 0.0298
# Epoch 47/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9684 - loss: 0.0762 - val_accuracy: 0.9926 - val_loss: 0.0289
# Epoch 48/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9690 - loss: 0.0735 - val_accuracy: 0.9918 - val_loss: 0.0282
# Epoch 49/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9705 - loss: 0.0720 - val_accuracy: 0.9934 - val_loss: 0.0263
# Epoch 50/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9674 - loss: 0.0748 - val_accuracy: 0.9951 - val_loss: 0.0259
# Epoch 51/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9717 - loss: 0.0702 - val_accuracy: 0.9951 - val_loss: 0.0242
# Epoch 52/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9723 - loss: 0.0672 - val_accuracy: 0.9926 - val_loss: 0.0254
# Epoch 53/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9727 - loss: 0.0678 - val_accuracy: 0.9967 - val_loss: 0.0227
# Epoch 54/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9725 - loss: 0.0661 - val_accuracy: 0.9934 - val_loss: 0.0193
# Epoch 55/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9713 - loss: 0.0600 - val_accuracy: 0.9918 - val_loss: 0.0219
# Epoch 56/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9756 - loss: 0.0560 - val_accuracy: 0.9967 - val_loss: 0.0191
# Epoch 57/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9739 - loss: 0.0567 - val_accuracy: 0.9967 - val_loss: 0.0187
# Epoch 58/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9760 - loss: 0.0533 - val_accuracy: 0.9967 - val_loss: 0.0169
# Epoch 59/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9723 - loss: 0.0600 - val_accuracy: 0.9967 - val_loss: 0.0185
# Epoch 60/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9752 - loss: 0.0578 - val_accuracy: 0.9959 - val_loss: 0.0182
# Epoch 61/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9791 - loss: 0.0527 - val_accuracy: 0.9951 - val_loss: 0.0191
# Epoch 62/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9760 - loss: 0.0539 - val_accuracy: 0.9967 - val_loss: 0.0154
# Epoch 63/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9778 - loss: 0.0494 - val_accuracy: 0.9959 - val_loss: 0.0152
# Epoch 64/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9803 - loss: 0.0499 - val_accuracy: 0.9959 - val_loss: 0.0138
# Epoch 65/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9783 - loss: 0.0500 - val_accuracy: 0.9975 - val_loss: 0.0145
# Epoch 66/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9780 - loss: 0.0494 - val_accuracy: 0.9975 - val_loss: 0.0134
# Epoch 67/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9774 - loss: 0.0507 - val_accuracy: 0.9992 - val_loss: 0.0111
# Epoch 68/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9766 - loss: 0.0494 - val_accuracy: 0.9975 - val_loss: 0.0125
# Epoch 69/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9797 - loss: 0.0480 - val_accuracy: 0.9967 - val_loss: 0.0119
# Epoch 70/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9811 - loss: 0.0435 - val_accuracy: 0.9992 - val_loss: 0.0091
# Epoch 71/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9774 - loss: 0.0450 - val_accuracy: 0.9967 - val_loss: 0.0099
# Epoch 72/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9834 - loss: 0.0415 - val_accuracy: 0.9975 - val_loss: 0.0107
# Epoch 73/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9836 - loss: 0.0405 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 74/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9850 - loss: 0.0406 - val_accuracy: 0.9943 - val_loss: 0.0141
# Epoch 75/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9824 - loss: 0.0430 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 76/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9809 - loss: 0.0415 - val_accuracy: 0.9992 - val_loss: 0.0082
# Epoch 77/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9850 - loss: 0.0367 - val_accuracy: 0.9984 - val_loss: 0.0079
# Epoch 78/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9840 - loss: 0.0373 - val_accuracy: 0.9975 - val_loss: 0.0085
# Epoch 79/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9836 - loss: 0.0350 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 80/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9842 - loss: 0.0364 - val_accuracy: 0.9984 - val_loss: 0.0070
# Epoch 81/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9856 - loss: 0.0350 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 82/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9838 - loss: 0.0345 - val_accuracy: 0.9984 - val_loss: 0.0070
# Epoch 83/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9838 - loss: 0.0331 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 84/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9854 - loss: 0.0321 - val_accuracy: 0.9984 - val_loss: 0.0069
# Epoch 85/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9856 - loss: 0.0329 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 86/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9824 - loss: 0.0358 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 87/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9858 - loss: 0.0315 - val_accuracy: 0.9984 - val_loss: 0.0063
# Epoch 88/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9867 - loss: 0.0291 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 89/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9879 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 90/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9852 - loss: 0.0327 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 91/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9852 - loss: 0.0324 - val_accuracy: 0.9984 - val_loss: 0.0065
# Epoch 92/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9883 - loss: 0.0285 - val_accuracy: 0.9975 - val_loss: 0.0066
# Epoch 93/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9899 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 94/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9856 - loss: 0.0299 - val_accuracy: 0.9975 - val_loss: 0.0063
# Epoch 95/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9877 - loss: 0.0281 - val_accuracy: 0.9992 - val_loss: 0.0055
# Epoch 96/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9895 - loss: 0.0260 - val_accuracy: 0.9984 - val_loss: 0.0059
# Epoch 97/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9897 - loss: 0.0287 - val_accuracy: 0.9959 - val_loss: 0.0075
# Epoch 98/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9883 - loss: 0.0288 - val_accuracy: 0.9992 - val_loss: 0.0060
# Epoch 99/100
# 10/10 - 0s - 8ms/step - accuracy: 0.9873 - loss: 0.0298 - val_accuracy: 0.9992 - val_loss: 0.0051
# Epoch 100/100
# 10/10 - 0s - 7ms/step - accuracy: 0.9904 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0046
